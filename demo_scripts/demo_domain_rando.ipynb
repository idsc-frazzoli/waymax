# %%
import jax
import jax.numpy as jnp
import plotly.graph_objs as go
import numpy as np

import dataclasses

from waymax.config import LinearCombinationRewardConfig, EnvironmentConfig
from waymax.dynamics.tricycle_model import TricycleModel
from waymax.env.gokart_environment_dr import GokartRacingDREnvironment
from waymax.utils.gokart_config import GoKartGeometry, PajieckaParams, TricycleParams
from waymax.datatypes.gokart_obs import GokartObservation

from gocarx.rl.ppo.evaluate import plotly_scatter
# Out:
# 2024-11-16 11:28:18.156233: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731756498.172719   13084 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731756498.177040   13084 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
from PIL import Image

# Load the images
img_noDR = Image.open("/workspaces/gocarx/submodules/waymax/demo_scripts/png/demo_noDR.png").convert("RGBA")
imgDR = Image.open("/workspaces/gocarx/submodules/waymax/demo_scripts/png/demo_DR.png").convert("RGBA")

# Resize images to the same dimensions if necessary
imgDR = imgDR.resize(img_noDR.size)

# Blend the images (adjust alpha for transparency)
overlayed = Image.alpha_composite(img_noDR, imgDR)

# Save or display the result
# overlayed.save("combined_overlay.png")
overlayed.show()
# Out:
# <PIL.Image.Image image mode=RGBA size=1132x890>
